# %% [markdown]
# <a href="https://colab.research.google.com/github/realmeelo/AI_Assignment/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install Libraries
# !pip install tensorflow opencv-python scikit-learn tf2onnx onnx pillow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
#@title Import Libraries
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import tf2onnx
import onnx

# %%
#@title Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("="*60)
print("FALL ARMYWORM DETECTION - AI MODEL TRAINING")
print("="*60)
# Out:
# ============================================================
# FALL ARMYWORM DETECTION - AI MODEL TRAINING
# ============================================================

# %%
#@title Clone Dataset Repository
# !git clone https://github.com/obasekore/Spodopera_DL_dataset.git /content/Spodopera_DL_dataset
!
# Out:
# fatal: destination path '/content/Spodopera_DL_dataset' already exists and is not an empty directory.

# %%
#@title Configuration
DATA_PATH = '/content/Spodopera_DL_dataset'  #Change this to your dataset path
IMG_SIZE = (224, 224)
NUM_CLASSES = 3  #Adjust based on your classes
EPOCHS = 20
BATCH_SIZE = 32
MODEL_TYPE = 'transfer_learning'  #'cnn' or 'transfer_learning'

# %%
#@title Load Dataset
print("\n[1/7] Loading dataset...")
images = []
labels = []
class_names = sorted(os.listdir(DATA_PATH))

for class_idx, class_name in enumerate(class_names):
    class_path = os.path.join(DATA_PATH, class_name)
    if not os.path.isdir(class_path):
        continue

    print(f"Loading {class_name}...")
    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)
        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, IMG_SIZE)
            images.append(img)
            labels.append(class_idx)
        except Exception as e:
            print(f"Error loading {img_path}: {e}")

X = np.array(images)
y = np.array(labels)
print(f"✓ Loaded {len(X)} images across {len(class_names)} classes: {class_names}")
# Out:
# [1/7] Loading dataset...
# Loading .git...
# Error loading /content/Spodopera_DL_dataset/.git/logs: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/info: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/HEAD: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/refs: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/hooks: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/objects: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/description: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/config: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/packed-refs: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/index: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/.git/branches: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Loading all...
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.20 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-25 at 11.54.52 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.38.01 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.51 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.06 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.58 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.24.22 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.24 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.21 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 8.39.21 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.44 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.13 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.13 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.41 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.20 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.03.53 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.30 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.52 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.00.29 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.18.19 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.55 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.11 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.26.25 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.20 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.59 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.11 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.07 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.34.17 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-25 at 11.55.00 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.44.25 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.26 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.38.40 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.02 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.39.44 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.39.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.54 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.03 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.57 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.25 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.27 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.12 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.06.32 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.48.51 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.48.25 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.56.06 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.06 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.12 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.49.16 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.32 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.55 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.54.41 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.36 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.01 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.37.53 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.33 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.48 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.48 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.21 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.06.32 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.04.21 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.43.20 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.47 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.37 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.02 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.00 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.14 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.17 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.11.00 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.47 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.32.16 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 11.03.10 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.00 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.18 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.38.16 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.26.11 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.00.09 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.32.50 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.46 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.22 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.01 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.46 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.18 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.40 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.15 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.11 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.17.51 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.16 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.40.42 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.47 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.39 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.33 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.55 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.05 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.42 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.56 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.48 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.46 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.13.04 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.48.42 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.57.07 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.32 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.52 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.49 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.56.36 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.59 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.03.20 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.44.11 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.37.47 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.00 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.27 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.06 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.41.44 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.36 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.52 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.33.31 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.54.51 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.04 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.08 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.31 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.34.35 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.37.09 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.44.57 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.23 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.10 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.43.52 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.56.21 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.52.52 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.33 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 11.03.08 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.01 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.55.37 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.41.16 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.16 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.35 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.10 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.04.06 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.34.01 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.50 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.44.57 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.03.43 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.37 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.50.06 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.44.56 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.01 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.29 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.58 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.47.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.24.36 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.26.51 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.53.10 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.45.56 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.15.05 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.38 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.40.09 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.17.34 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 10.35.28 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.41.35 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.49.43 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.14 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.27.00 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.49.00 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 1.37.31 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.35.44 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.54.18 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.03.01 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.46.29 PM (1).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 8.40.45 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.07 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.44.56 PM (2).xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 12.03.58 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 7.17.15 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 9.43.17 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-26 at 11.03.13 AM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.44.46 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.09 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/groundTruthTable.mat: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-10-28 at 2.48.28 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error loading /content/Spodopera_DL_dataset/all/WhatsApp Image 2018-11-08 at 6.40.58 PM.xml: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Loading armyWorm...
# ✓ Loaded 1048 images across 4 classes: ['.git', 'README.md', 'all', 'armyWorm']
